# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
file_path = r'/content/drive/MyDrive/Algoritimía y programación/alzheimers_disease_data.csv'
data = pd.read_csv(file_path)
data
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0          4751   73       0          0               2  22.927749        0
# 1          4752   89       0          0               0  26.827681        0
# 2          4753   73       0          3               1  17.795882        0
# 3          4754   74       1          0               1  33.800817        1
# 4          4755   89       0          0               0  20.716974        0
# ...         ...  ...     ...        ...             ...        ...      ...
# 2144       6895   61       0          0               1  39.121757        0
# 2145       6896   75       0          0               2  17.857903        0
# 2146       6897   77       0          0               1  15.476479        0
# 2147       6898   78       1          3               1  15.299911        0
# 2148       6899   72       0          0               2  33.289738        0
#
# ...

# %%
data.columns
# Out:
# Index(['PatientID', 'Age', 'Gender', 'Ethnicity', 'EducationLevel', 'BMI',
#        'Smoking', 'AlcoholConsumption', 'PhysicalActivity', 'DietQuality',
#        'SleepQuality', 'FamilyHistoryAlzheimers', 'CardiovascularDisease',
#        'Diabetes', 'Depression', 'HeadInjury', 'Hypertension', 'SystolicBP',
#        'DiastolicBP', 'CholesterolTotal', 'CholesterolLDL', 'CholesterolHDL',
#        'CholesterolTriglycerides', 'MMSE', 'FunctionalAssessment',
#        'MemoryComplaints', 'BehavioralProblems', 'ADL', 'Confusion',
#        'Disorientation', 'PersonalityChanges', 'DifficultyCompletingTasks',
#        'Forgetfulness', 'Diagnosis', 'DoctorInCharge'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2149 entries, 0 to 2148
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PatientID                  2149 non-null   int64
#  1   Age                        2149 non-null   int64
#  2   Gender                     2149 non-null   int64
#  3   Ethnicity                  2149 non-null   int64
#  4   EducationLevel             2149 non-null   int64
#  5   BMI                        2149 non-null   float64
#  6   Smoking                    2149 non-null   int64
#  7   AlcoholConsumption         2149 non-null   float64
#  8   PhysicalActivity           2149 non-null   float64
#  9   DietQuality                2149 non-null   float64
#  10  SleepQuality               2149 non-null   float64
#  11  FamilyHistoryAlzheimers    2149 non-null   int64
#  12  CardiovascularDisease      2149 non-null   int64
# ...

# %%
data.describe()
# Out:
#          PatientID          Age       Gender    Ethnicity  EducationLevel  \
# count  2149.000000  2149.000000  2149.000000  2149.000000     2149.000000
# mean   5825.000000    74.908795     0.506282     0.697534        1.286645
# std     620.507185     8.990221     0.500077     0.996128        0.904527
# min    4751.000000    60.000000     0.000000     0.000000        0.000000
# 25%    5288.000000    67.000000     0.000000     0.000000        1.000000
# 50%    5825.000000    75.000000     1.000000     0.000000        1.000000
# 75%    6362.000000    83.000000     1.000000     1.000000        2.000000
# max    6899.000000    90.000000     1.000000     3.000000        3.000000
#
#                BMI      Smoking  AlcoholConsumption  PhysicalActivity  \
# count  2149.000000  2149.000000         2149.000000       2149.000000
# mean     27.655697     0.288506           10.039442          4.920202
# std       7.217438     0.453173            5.757910          2.857191
# ...

# %%
#Eliminamos la columna que no aporta información a la base de datos.
bases = data.drop(columns=['DoctorInCharge'])

# %%
#Miramos como queda.
bases
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0          4751   73       0          0               2  22.927749        0
# 1          4752   89       0          0               0  26.827681        0
# 2          4753   73       0          3               1  17.795882        0
# 3          4754   74       1          0               1  33.800817        1
# 4          4755   89       0          0               0  20.716974        0
# ...         ...  ...     ...        ...             ...        ...      ...
# 2144       6895   61       0          0               1  39.121757        0
# 2145       6896   75       0          0               2  17.857903        0
# 2146       6897   77       0          0               1  15.476479        0
# 2147       6898   78       1          3               1  15.299911        0
# 2148       6899   72       0          0               2  33.289738        0
#
# ...

# %%
#Eliminamos las columnas que contengan información que no aporte nada al análisis que haremos.
bases_2 = bases.drop(columns = ['Ethnicity', 'EducationLevel'])
bases_2
# Out:
#       PatientID  Age  Gender        BMI  Smoking  AlcoholConsumption  \
# 0          4751   73       0  22.927749        0           13.297218
# 1          4752   89       0  26.827681        0            4.542524
# 2          4753   73       0  17.795882        0           19.555085
# 3          4754   74       1  33.800817        1           12.209266
# 4          4755   89       0  20.716974        0           18.454356
# ...         ...  ...     ...        ...      ...                 ...
# 2144       6895   61       0  39.121757        0            1.561126
# 2145       6896   75       0  17.857903        0           18.767261
# 2146       6897   77       0  15.476479        0            4.594670
# 2147       6898   78       1  15.299911        0            8.674505
# 2148       6899   72       0  33.289738        0            7.890703
#
#       PhysicalActivity  DietQuality  SleepQuality  FamilyHistoryAlzheimers  \
# ...

# %%
#Miramos si existen valores nulos.
print(bases_2.isnull().sum())
# Out:
# PatientID                    0
# Age                          0
# Gender                       0
# BMI                          0
# Smoking                      0
# AlcoholConsumption           0
# PhysicalActivity             0
# DietQuality                  0
# SleepQuality                 0
# FamilyHistoryAlzheimers      0
# CardiovascularDisease        0
# Diabetes                     0
# Depression                   0
# HeadInjury                   0
# Hypertension                 0
# SystolicBP                   0
# DiastolicBP                  0
# CholesterolTotal             0
# CholesterolLDL               0
# CholesterolHDL               0
# CholesterolTriglycerides     0
# MMSE                         0
# FunctionalAssessment         0
# MemoryComplaints             0
# BehavioralProblems           0
# ADL                          0
# Confusion                    0
# Disorientation               0
# PersonalityChanges           0
# DifficultyCompletingTasks    0
# ...

# %%
print(bases_2.isna().sum())
# Out:
# PatientID                    0
# Age                          0
# Gender                       0
# BMI                          0
# Smoking                      0
# AlcoholConsumption           0
# PhysicalActivity             0
# DietQuality                  0
# SleepQuality                 0
# FamilyHistoryAlzheimers      0
# CardiovascularDisease        0
# Diabetes                     0
# Depression                   0
# HeadInjury                   0
# Hypertension                 0
# SystolicBP                   0
# DiastolicBP                  0
# CholesterolTotal             0
# CholesterolLDL               0
# CholesterolHDL               0
# CholesterolTriglycerides     0
# MMSE                         0
# FunctionalAssessment         0
# MemoryComplaints             0
# BehavioralProblems           0
# ADL                          0
# Confusion                    0
# Disorientation               0
# PersonalityChanges           0
# DifficultyCompletingTasks    0
# ...

# %%
#Miramos si hay valores repetidos.
print(bases_2.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2144    False
# 2145    False
# 2146    False
# 2147    False
# 2148    False
# Length: 2149, dtype: bool

# %%
print(data.duplicated().sum())
# Out:
# 0

# %%
#Ejecutamos el DataFrame
bases_2
# Out:
#       PatientID  Age  Gender        BMI  Smoking  AlcoholConsumption  \
# 0          4751   73       0  22.927749        0           13.297218
# 1          4752   89       0  26.827681        0            4.542524
# 2          4753   73       0  17.795882        0           19.555085
# 3          4754   74       1  33.800817        1           12.209266
# 4          4755   89       0  20.716974        0           18.454356
# ...         ...  ...     ...        ...      ...                 ...
# 2144       6895   61       0  39.121757        0            1.561126
# 2145       6896   75       0  17.857903        0           18.767261
# 2146       6897   77       0  15.476479        0            4.594670
# 2147       6898   78       1  15.299911        0            8.674505
# 2148       6899   72       0  33.289738        0            7.890703
#
#       PhysicalActivity  DietQuality  SleepQuality  FamilyHistoryAlzheimers  \
# ...

# %% [markdown]
# Al mirar la base de datos, encontramos que no hay valores nulos ni valores duplicados. Sin embargo, hay que tener en cuenta que dichos valores que aparecen como 0 representan información, ya que son valores en formato binario que indican la no presencia de alguna característica en dicha celda. En cuanto a lo demás, se han eliminado columnas que no afectaban el análisis de los datos, datos secundarios, como el nivel de educación o columnas que directamente no tenían nada de información, como la primera que eliminamos.
